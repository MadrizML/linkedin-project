# %%
import pandas as pd
import glob

# %%
def clean_search(path):
    print('Cleaning: ' + path)
    df = pd.read_csv(path)
    df.drop_duplicates(keep='last', inplace=True)
    df.reset_index(drop=True, inplace=True)
    df.to_csv(path, index=False)

# %%
def clean_csv(path):

    print('\nCleaning: ' + path)

    with open(path, 'rt') as f:
        files = f.read().split(",")

    #, newline='\r\n'    

    files = [file.strip("\"\"") for file in files]

    page_list = []

    for file in files:
        if len(file) > 45:
            for second in file.split("\n"):
                page_list.append(second.strip("\"\""))
        else:
            page_list.append(file)

    page_list = page_list[:-1]

    page_list = list(set(page_list))

    with open(path, 'w', newline='') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(page_list)


for path in glob.glob('job_links/*.csv'):
    clean_csv(path)
# Out:
# Cleaning: job_links/data_scientist_spain_links.csv
#
# Cleaning: job_links/data_python_european_union_links.csv
#
# Cleaning: job_links/data_analyst_spain_links.csv
#
# Cleaning: job_links/business_intelligence_germany_links.csv
#
# Cleaning: job_links/data_analyst_germany_links.csv
#
# Cleaning: job_links/data_scientist_germany_links-Copy1.csv
#
# Cleaning: job_links/data_analyst_lisbon_links.csv
#
# Cleaning: job_links/business_intelligence_portugal_links.csv
#
# Cleaning: job_links/data_scientist_germany_links.csv
#
# Cleaning: job_links/data_analyst_portugal_links.csv
#
# Cleaning: job_links/data_scientist_portugal_links.csv
#
# Cleaning: job_links/data_(analist_OR_scientist)_European_Union_links.csv

# %%
path = 'linkedin_search.csv'
    
clean_search(path)

# %%
import pandas as pd
import glob
import csv

path = 'job_links/data_scientist_germany_links-Copy1.csv'

with open(path, 'rt') as f:
    files = f.read().split(",")

#, newline='\r\n'    

files = [file.strip("\"\"") for file in files]

page_list = []

for file in files:
    if len(file) > 45:
        for second in file.split("\n"):
            page_list.append(second.strip("\"\""))
    else:
        page_list.append(file)

page_list = page_list[:-1]

# %%
with open(path, 'w', newline='') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(page_list)

# %%
with open(path, 'r') as f:
    reader = csv.reader(f)
    your_list = list(reader)
    
your_list = [a for sub in your_list for a in sub ]
your_list
# Out:
# ['https://www.linkedin.com/jobs/view/1569471324',
#  'https://www.linkedin.com/jobs/view/1582122097',
#  'https://www.linkedin.com/jobs/view/1545562096',
#  'https://www.linkedin.com/jobs/view/1601511206',
#  'https://www.linkedin.com/jobs/view/1617573306',
#  'https://www.linkedin.com/jobs/view/1563377056',
#  'https://www.linkedin.com/jobs/view/1528976276',
#  'https://www.linkedin.com/jobs/view/1555976433',
#  'https://www.linkedin.com/jobs/view/1621096629',
#  'https://www.linkedin.com/jobs/view/1625608782',
#  'https://www.linkedin.com/jobs/view/1578584736',
#  'https://www.linkedin.com/jobs/view/1494681616',
#  'https://www.linkedin.com/jobs/view/1580551794',
#  'https://www.linkedin.com/jobs/view/1561199177',
#  'https://www.linkedin.com/jobs/view/1046873581',
#  'https://www.linkedin.com/jobs/view/1492495738',
#  'https://www.linkedin.com/jobs/view/1573131626',
